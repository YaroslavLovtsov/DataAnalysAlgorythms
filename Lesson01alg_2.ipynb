# %% [markdown]
# **Найти ошибку в коде**

# %%
for i in range(1000):
  y_pred = np.dot(W, X)
  err = calc_mse(y, y_pred)
  '''for ii in range(W.shape[0]):
  W[ii] -= alpha * (1/n * 2 * np.sum(X[ii] * (y_pred - y)))'''
  W -= (alpha * (1/n * 2 * np.sum(X * (y_pred - y))))
  if i % 100 == 0:
    print(i, W, err)

# %% [markdown]
# Я думаю, что ошибка здесь в том, что вот это вот выражение
# np.sum(X * (y_pred - y))
# это будет сумма скалярных произведений, которая нам не нужна. Правильно - как в приведенном ниже фрагементе кода

# %%
for i in range(1000):
  y_pred = np.dot(W, X)
  err = calc_mse(y, y_pred)
  '''for ii in range(W.shape[0]):
  W[ii] -= alpha * (1/n * 2 * np.sum(X[ii] * (y_pred - y)))'''
  W -= (alpha * (1/n * 2 * np.sum(y_pred - y))) * X
  if i % 100 == 0:
    print(i, W, err)
